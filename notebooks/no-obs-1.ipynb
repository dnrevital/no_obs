# %% [markdown]
# ## Imports

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Images Utility

# %%
def load_images_from_folder(folder):
    imnames = []
    images = []
    for imname in os.listdir(folder):
        imrgb = cv2.imread(os.path.join(folder,imname))
        im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2GRAY)        
        if im is not None:
            imnames.append(imname)
            images.append(im)
    return imnames, images

# %% [markdown]
# ## Load & Process Loop

# %%
no_obs_folder='../input/no-obstacle-test/test_image_pairs/not_obstacle'
no_obs_imnames, no_obs_images = load_images_from_folder(no_obs_folder)
obs_folder='../input/no-obstacle-test/test_image_pairs/obstacle'
obs_imnames, obs_images = load_images_from_folder(obs_folder)

# %% [markdown]
# ## Read Obstacle Images

# %%
im = obs_images[0]
w = im.shape[1]
im1 = im[:,:w//2]
im2 = im[:,w//2:]

# %% [markdown]
# > ## Show Separated Obstacle Images

# %%
plt.imshow(im1, cmap='gray', vmin=0, vmax=255)
plt.title('left half = source')
plt.show()

plt.imshow(im2, cmap='gray', vmin=0, vmax=255)
plt.title('right half = current')
plt.show()

# %% [markdown]
# > ## Create Diff Obstacle Image by Subtraction[](http://)

# %%
plain = cv2.subtract(im2, im1)
plt.imshow(plain, cmap='gray', vmin=0, vmax=255)
plt.title('Obstacle Diff')
plt.show()

# %% [markdown]
# * ## Read Non-Obstacle Images

# %%
im = no_obs_images[0]
w = im.shape[1]
im1 = im[:,:w//2]
im2 = im[:,w//2:]

# %% [markdown]
# ## Show Separated Non-Obstacle Images

# %%
plt.imshow(im1, cmap='gray', vmin=0, vmax=255)
plt.title('left half = source')
plt.show()

plt.imshow(im2, cmap='gray', vmin=0, vmax=255)
plt.title('right half = current')
plt.show()

# %% [markdown]
# ## Create Diff No-Obstacle Image by Subtraction

# %%
plain = cv2.subtract(im2, im1)
plt.imshow(plain, cmap='gray', vmin=0, vmax=255)
plt.title('Non-Obstacle Diff')
plt.show()
